# %% [markdown]
# # Data Project 1: Analysis of Danish export from 2000-2018 by "Broad Economics Category"

# %% [markdown]
# ## Import packages

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ipywidgets as widgets

# %% [markdown]
# ## Reading the dataset

# %%
filepath = './dataproject/DK_export.xlsx' 
pd.read_excel(filepath).head(25) #Printing the first 25 lines of the dataset
# Out:
#    Total external trade by imports and exports, seasonal adjustment, kind and time  \
# 0                                        Units: m DKK
# 1                                                 NaN
# 2                                             Exports
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %% [markdown]
# ## Cleaning the data

# %% [markdown]
# ### Removing the two first rows as well as all rows from 10 and onwards.

# %%
exp = pd.read_excel(filepath, skiprows = 2) 
Dropped = ['Unnamed: 0', 'Unnamed: 1']
exp.drop(Dropped, axis = 1, inplace = True) 
exp.drop(exp.index[10:], inplace=True)
exp.head(5)
# Out:
#                                           Unnamed: 2      1997      1998  \
# 0                                              TOTAL  324271.3  326503.7
# 1          Live animals, Food, Beverages And Tobacco   75623.1   71598.3
# 2            Crude Materials, Inedible, Except Fuels   13712.9   13027.8
# 3                     Chemicals And Related Products   35380.5   36662.9
# 4  Manufactured Goods Classified Chiefly By Material   36244.5   37376.8
#
#        1999      2000      2001      2002      2003      2004      2005  \
# 0  351916.4  408238.8  424669.5  442753.6  429272.0  452399.7  493678.6
# 1   72690.7   78689.5   87516.2   85802.4   82457.2   83776.6   87654.0
# 2   13038.5   15382.5   14999.2   15870.6   15995.6   16986.0   17188.1
# 3   42452.6   49045.9   54302.7   58243.5   60182.6   61406.0   68837.6
# 4   39091.2   43400.0   44054.7   44395.1   43380.3   45180.4   47778.4
#
#      ...         2009      2010      2011      2012      2013      2014  \
# ...

# %% [markdown]
# ### Rename first column, "Unnamed: 2" as "Category"

# %%
exp.rename(columns = {'Unnamed: 2':'year'}, inplace=True)

# %% [markdown]
# ### Transposing the data in order to have each rows representing a year.

# %%
exp_t=exp.T
exp_t
exp = exp_t
exp.head(5)
# Out:
#            0                                          1  \
# year   TOTAL  Live animals, Food, Beverages And Tobacco
# 1997  324271                                    75623.1
# 1998  326504                                    71598.3
# 1999  351916                                    72690.7
# 2000  408239                                    78689.5
#
#                                             2                               3  \
# year  Crude Materials, Inedible, Except Fuels  Chemicals And Related Products
# 1997                                  13712.9                         35380.5
# 1998                                  13027.8                         36662.9
# 1999                                  13038.5                         42452.6
# 2000                                  15382.5                         49045.9
#
#                                                       4  \
# year  Manufactured Goods Classified Chiefly By Material
# ...

# %% [markdown]
# ### Removing the top horizontal index.

# %% [markdown]
# Running this section of the code twice will results in replacing the category names with the dataset of 1997. If already done go back to importing the dataset once again.

# %%
exp.columns = exp.iloc[0]
exp.drop(exp.index[0], inplace=True)
exp.head(5)
# Out:
# year   TOTAL Live animals, Food, Beverages And Tobacco  \
# 1997  324271                                   75623.1
# 1998  326504                                   71598.3
# 1999  351916                                   72690.7
# 2000  408239                                   78689.5
# 2001  424670                                   87516.2
#
# year Crude Materials, Inedible, Except Fuels Chemicals And Related Products  \
# 1997                                 13712.9                        35380.5
# 1998                                 13027.8                        36662.9
# 1999                                 13038.5                        42452.6
# 2000                                 15382.5                        49045.9
# 2001                                 14999.2                        54302.7
#
# year Manufactured Goods Classified Chiefly By Material  \
# 1997                                           36244.5
# 1998                                           37376.8
# ...

# %% [markdown]
# ### Calculating yearly growth rate in %

# %%
exp_perc = exp.pct_change()*100
exp_perc.drop(exp_perc.index[0], inplace=True)
exp_perc.head()
# Out:
# year      TOTAL  Live animals, Food, Beverages And Tobacco  \
# 1998   0.688436                                  -5.322183
# 1999   7.783281                                   1.525735
# 2000  16.004483                                   8.252500
# 2001   4.024777                                  11.217126
# 2002   4.258394                                  -1.958266
#
# year  Crude Materials, Inedible, Except Fuels  Chemicals And Related Products  \
# 1998                                -4.996026                        3.624595
# 1999                                 0.082132                       15.791713
# 2000                                17.977528                       15.530969
# 2001                                -2.491793                       10.718123
# 2002                                 5.809643                        7.257098
#
# year  Manufactured Goods Classified Chiefly By Material  \
# 1998                                           3.124060
# ...

# %%
exp_perc['time2'] = np.arange(1998,2019)
# Out:
# year      TOTAL  Live animals, Food, Beverages And Tobacco  \
# 1998   0.688436                                  -5.322183
# 1999   7.783281                                   1.525735
# 2000  16.004483                                   8.252500
# 2001   4.024777                                  11.217126
# 2002   4.258394                                  -1.958266
# 2003  -3.044944                                  -3.898725
# 2004   5.387656                                   1.600103
# 2005   9.124431                                   4.628261
# 2006   9.335851                                   8.382390
# 2007   2.542112                                   0.664200
# 2008   6.397162                                   5.086242
# 2009 -16.519652                                  -7.241539
# 2010  10.024489                                   6.929803
# 2011  11.744132                                   6.931751
# 2012   1.675777                                   4.552930
# ...

# %%
def _plot_timeseries(df, x, y):
    fig = plt.figure(dpi=100)
    ax = fig.add_subplot(1,1,1)
    I = (df.time2 >= y[0]) & (df.time2 <= y[1])
    series = df.loc[I,[x]]
    years = np.arange(y[0],y[1]+1)
    ax.plot(years,series)
    plt.xticks(np.arange(y[0],y[1]+1, 2.0))

    return fig, ax
    
def plot_timeseries(df):
    varlist = [col for col in exp_perc.columns[:-1]]

    widgets.interact(_plot_timeseries,
    df = widgets.fixed(df),
    x = widgets.Dropdown(
        description='Variable', 
        options=varlist, 
        value='TOTAL'),
    y=widgets.IntRangeSlider(
        description="Years",
        min=1998,
        max=2018,
        value=[1998, 2018],
        continuous_update=False,)

    ); 

    
plot_timeseries(exp_perc)
# Out:
# interactive(children=(Dropdown(description='Variable', options=('TOTAL', 'Live animals, Food, Beverages And To…

# %%
varlist
# Out:
# ['TOTAL',
#  'Live animals, Food, Beverages And Tobacco',
#  'Crude Materials, Inedible, Except Fuels',
#  'Chemicals And Related Products',
#  'Manufactured Goods Classified Chiefly By Material',
#  'Machinery (excl. Transport Equipment)',
#  'Transport Equipment',
#  'Miscellaneous Manufactured Articles',
#  'Mineral Fuels, Lubricants And Related Materials',
#  'Vessels, aircraft etc.']

# %% [markdown]
# # Descriptive statistics

# %% [markdown]
# ## Outputting basic desriptive statistics of the dataset

# %%
exp.describe() #Virker sjovt nok ikke da den tager index.
# Out:
# year       TOTAL  Live animals, Food, Beverages And Tobacco  \
# count       22.0                                       22.0
# unique      22.0                                       22.0
# top     540894.8                                    99679.0
# freq         1.0                                        1.0
#
# year    Crude Materials, Inedible, Except Fuels  \
# count                                      22.0
# unique                                     22.0
# top                                     21872.4
# freq                                        1.0
#
# year    Chemicals And Related Products  \
# count                             22.0
# unique                            22.0
# top                            61406.0
# freq                               1.0
#
# year    Manufactured Goods Classified Chiefly By Material  \
# count                                                22.0
# unique                                               22.0
# ...

# %% [markdown]
# ## Creating a boxplot of the XXX

# %% [markdown]
# # Presentation of data

# %% [markdown]
# ## Calculate each category's contribution to the total export

# %% [markdown]
# ## Show results as line chart
